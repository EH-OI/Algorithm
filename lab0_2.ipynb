# %%
import random

n,m = map(int, input().split())

list_n = sorted(random.sample(range(1, 100), n))
list_m = sorted(random.sample(range(1, 100), m))

list_union = []
list_intersection = []

for num in list_m:
    list_union.append(num)

for num in list_n:
    if num in list_m:
        list_intersection.append(num)
    else: list_union.append(num)

list_union.sort()
print("집합 A -", list_n)
print("집합 B -", list_m)
print("합집합 -", list_union)
print("교집합 -", list_intersection)
# Out:
#  11 12
# 집합 A - [17, 23, 27, 33, 38, 51, 61, 63, 64, 88, 90]
# 집합 B - [9, 18, 24, 25, 37, 49, 55, 67, 72, 73, 86, 95]
# 합집합 - [9, 17, 18, 23, 24, 25, 27, 33, 37, 38, 49, 51, 55, 61, 63, 64, 67, 72, 73, 86, 88, 90, 95]
# 교집합 - []
